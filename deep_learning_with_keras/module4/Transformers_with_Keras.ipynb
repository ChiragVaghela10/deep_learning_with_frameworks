# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Transformers with Keras
#
# Estimated time needed **45** mins

# %% [markdown]
# In this lab, we will learn how to use the Keras library to build a transformer using a sequence-to-sequence architecture with self-attention for translation. We will train the model using a sample dataset and then use this model for English to Spanish translation.

# %% [markdown]
# # Objectives for this Notebook
# * How to use the Keras library to build transformers model
# * Train the transformer model using a given dataset
# * Use the trained transformer model to translate

# %% [markdown]
# <h2>Table of Contents</h2>
#
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 4>
# 1. <a href="#Import-Keras-and-Packages">Import Keras and Packages</a><br>
# 2. <a href="#Step-1:-Data-Preparation">Step 1: Data Preparation</a><br>
# 3. <a href="#Step-2:-Self-Attention-Layer">Step 2: Self-Attention Layer</a><br>
# 4. <a href="#Step-3:-Model-Architecture">Step 3: Model Architecture</a><br>
# 5. <a href="#Step-4:-Training-the-Model">Step 4: Training the Model</a><br>
# 6. <a href="#Step-5:-Plotting-the-training-loss">Step 5: Plotting the training loss</a><br>
#
# </font>
# </div>

# %% [markdown]
# ## Import Keras and Packages

# %% [markdown]
# Let's start by importing the keras libraries and the packages that we would need to build a neural network.

# %% [markdown]
# The following required libraries are __not__ pre-installed in the Skills Network Labs environment. __You will need to run the following cell__ to install them:

# %%
# !pip install tensorflow==2.17.1
# !pip install matplotlib==3.9.2

print("==== All required libraries are installed =====")

# %% [markdown]
# #### Suppress the tensorflow warning messages
# We use the following code to  suppress the warning messages due to use of CPU architechture for tensoflow.
#
# You may want to **comment out** these lines if you are using the GPU architechture

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %% [markdown]
# ##### To use Keras, you will also need to install a backend framework – such as TensorFlow.
#
# If you install TensorFlow 2.16 or above, it will install Keras by default.
#
# We are using the CPU version of tensorflow since we are dealing with smaller datasets.
# You may install the GPU version of tensorflow on your machine to accelarate the processing of larger datasets

# %% [markdown]
# ### Import the necessary libraries

# %%
import numpy as np
from keras.models import Model
from keras.layers import Input, LSTM, Dense, Embedding, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import backend as K
from keras.layers import Layer
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# # Step 1: Data Preparation
# We start by define the sentences and text for translation training
# Sentence Pairs: Defines a small dataset of English-Spanish sentence pairs.
# Target Sequences:
# Prepends "startseq" and appends "endseq" to each target sentence for the decoder to learn when to start and stop translating.

# %%
# Sample parallel sentences (English -> Spanish)
input_texts = [
    "Hello.", "How are you?", "I am learning machine translation.", "What is your name?", "I love programming."
]
target_texts = [
    "Hola.", "¿Cómo estás?", "Estoy aprendiendo traducción automática.", "¿Cuál es tu nombre?", "Me encanta programar."
]

target_texts = ["startseq " + x + " endseq" for x in target_texts]

# %% [markdown]
# ## Next, we convert the text from the sentences to tokens and create a vocabulary
# Tokenization: Uses Tokenizer to convert words into numerical sequences.

# %%
# Tokenization
input_tokenizer = Tokenizer()
input_tokenizer.fit_on_texts(input_texts)
input_sequences = input_tokenizer.texts_to_sequences(input_texts)

output_tokenizer = Tokenizer()
output_tokenizer.fit_on_texts(target_texts)
output_sequences = output_tokenizer.texts_to_sequences(target_texts)

input_vocab_size = len(input_tokenizer.word_index) + 1
output_vocab_size = len(output_tokenizer.word_index) + 1

# %% [markdown]
# ### Now pad the corresponding sentences
# Padding: Ensures all sequences have the same length.

# %%
# Padding
max_input_length = max([len(seq) for seq in input_sequences])
max_output_length = max([len(seq) for seq in output_sequences])

input_sequences = pad_sequences(input_sequences, maxlen=max_input_length, padding='post')
output_sequences = pad_sequences(output_sequences, maxlen=max_output_length, padding='post')

# %%
# Prepare the target data for training
decoder_input_data = output_sequences[:, :-1]
decoder_output_data = output_sequences[:, 1:]

# Convert to one-hot
decoder_output_data = np.array([np.eye(output_vocab_size)[seq] for seq in decoder_output_data])

# %% [markdown]
# # Step 2: Self-Attention Layer
# Self-attention is a mechanism that allows a model to **focus on relevant parts of the input sequence** while processing each word. This is particularly useful in:
# 1) Machine Translation (e.g., aligning words correctly)
# 2) Text Summarization
# 3) Speech Recognition
# 4) Image Processing (Vision Transformers)
# In this implementation, self-attention is used for text based sequence-to-sequence modeling.
#
#
# Self-Attention works for a given an input sequence by computing a weighted representation of all words for each position. It does so using three key components:
#
# 1. Query **(Q)**, Key **(K)**, and Value **(V)** Matrices
# For each word (token) in a sequence:
#
# Query (Q): What this word is looking for.
# Key (K): What this word represents.
# Value (V): The actual information in the word.
#
# 2. Compute **Attention Scores**
# Next, we **calculate the similarity between each query and key** using dot-product attention:
# Each word in a sequence attends to every other word based on these scores.
#
# 3. Apply **Scaling & Softmax**
# Since dot-product values can be large, we scale them.
# Next, Applying softmax converts scores into attention weights:

# %% [markdown]
# ### Self-Attention class
# In this implementation of self-attention layer:
# 1. We first initialize the weights in the **build** method, where:
#     1. **self.Wq**, **self.Wk**, **self.Wv** are the trainable weight matrices.
#     2. Their **shape is (feature_dim, feature_dim)**, meaning they transform input features into Q, K, and V representations.
# 2. Applying Attention using **call** method. The **call()** method:
#    1. Computes **Q, K, V** by multiplying inputs (encoder/decoder output) with their respective weight matrices.
#    2. Computes **dot-product attention scores** using K.batch_dot(q, k, axes=[2, 2]), resulting in a (batch_size, seq_len, seq_len) matrix.
#    3. **Scales** the scores to avoid large values.
#    4. Applies **softmax** to normalize the attention scores.
#    5. **Multiplies attention weights with V** to get the final output.
# 3. The **compute_output_shape** method defines the shape of the output tensor after the layer processes an input.
#     1. The output shape of the Self-Attention layer **remains the same** as the input shape.
#     2. The attention mechanism **transforms** the input but does not change its dimensions.4
#     3. If the attention layer changed the shape, you would modify compute_output_shape

# %%
# Define the Self-Attention Layer
class SelfAttention(Layer):
    def __init__(self, **kwargs):
        super(SelfAttention, self).__init__(**kwargs)

    def build(self, input_shape):
        feature_dim = input_shape[-1]
        # Weight matrices for Q, K, V
        self.Wq = self.add_weight(shape=(feature_dim, feature_dim), 
                                  initializer='glorot_uniform', 
                                  trainable=True, 
                                  name='Wq')
        self.Wk = self.add_weight(shape=(feature_dim, feature_dim), 
                                  initializer='glorot_uniform', 
                                  trainable=True, 
                                  name='Wk')
        self.Wv = self.add_weight(shape=(feature_dim, feature_dim), 
                                  initializer='glorot_uniform', 
                                  trainable=True, 
                                  name='Wv')
        super(SelfAttention, self).build(input_shape)

    def call(self, inputs):
        # Linear projections
        q = K.dot(inputs, self.Wq)  # Query
        k = K.dot(inputs, self.Wk)  # Key
        v = K.dot(inputs, self.Wv)  # Value

        # Scaled Dot-Product Attention
        scores = K.batch_dot(q, k, axes=[2, 2])  # (batch, seq_len, seq_len)
        scores = scores / K.sqrt(K.cast(K.shape(k)[-1], dtype=K.floatx()))  # Scale
        attention_weights = K.softmax(scores, axis=-1)  # Normalize

        # Weighted sum of values
        output = K.batch_dot(attention_weights, v)  # (batch, seq_len, feature_dim)
        return output

    def compute_output_shape(self, input_shape):
        return input_shape

# %% [markdown]
# # Step 3: Model Architecture
# The model follows an Encoder-Decoder structure:
#
# ### Encoder:
# 1) Takes input sentences (padded and tokenized).
# 2) Uses an Embedding layer (word representations) + LSTM (to process sequences).
#     1. The LSTMs are used as the **help process variable-length input sentences** and generate meaningful translations.
# 4) Outputs context vectors (hidden & cell states).
#
# ### Attention Layer
# 1) Applied to both the encoder and decoder outputs.
# 2) Helps the decoder focus on relevant words during translation.
#
# ### Decoder
# 1) Receives target sequences (shifted one step ahead).
# 2) Uses an LSTM with encoder states as initial states.
# 3) Applies self-attention for better learning.
# 4) Uses a Dense layer (Softmax) to predict the next word.

# %%
# Encoder
encoder_inputs = Input(shape=(max_input_length,))
encoder_embedding = Embedding(input_vocab_size, 256)(encoder_inputs)
encoder_lstm = LSTM(256, return_sequences=True, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
encoder_states = [state_h, state_c]

# Attention Mechanism
attention_layer = SelfAttention()(encoder_outputs)

# Decoder
decoder_inputs = Input(shape=(max_output_length - 1,))
decoder_embedding = Embedding(output_vocab_size, 256)(decoder_inputs)
decoder_lstm = LSTM(256, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_attention = SelfAttention()(decoder_outputs)  # Apply attention
decoder_dense = Dense(output_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_attention)

Full Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary
model.summary()

# %% [markdown]
# # Step 4: Training the Model
# Uses categorical_crossentropy as the loss function since output words are one-hot encoded.
# Trains using Adam optimizer for 100 epochs.

# %%
# Step 6: Train the Model
history_glorot_adam = model.fit([input_sequences, decoder_input_data], decoder_output_data, epochs=100, batch_size=16)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 21s 21s/step - accuracy: 0.0400 - loss: 2.8358
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step - accuracy: 0.2800 - loss: 2.7993
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step - accuracy: 0.2800 - loss: 2.7576
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step - accuracy: 0.2800 - loss: 2.7014
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - accuracy: 0.2800 - loss: 2.6208
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step - accuracy: 0.2800 - loss: 2.5087
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 600ms/step - accuracy: 0.2400 - loss: 2.3790
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step - accuracy: 0.2400 - loss: 2.3322
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - accuracy: 0.2400 - loss: 2.3652
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 578ms/step - accuracy: 0.2800 - loss: 2.2993
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step - accuracy: 0.3200 - loss: 2.2398
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.3200 - loss: 2.2129
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 580ms/step - accuracy: 0.2000 - loss: 2.1931
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step - accuracy: 0.2800 - loss: 2.1647
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.3200 - loss: 2.1210
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step - accuracy: 0.3200 - loss: 2.0633
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step - accuracy: 0.3200 - loss: 2.0010
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step - accuracy: 0.3200 - loss: 1.9490
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step - accuracy: 0.3200 - loss: 1.9127
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step - accuracy: 0.3200 - loss: 1.8737
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step - accuracy: 0.3200 - loss: 1.8166
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step - accuracy: 0.3200 - loss: 1.7542
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.3200 - loss: 1.7071
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step - accuracy: 0.3200 - loss: 1.6779
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step - accuracy: 0.3200 - loss: 1.6509
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step - accuracy: 0.3200 - loss: 1.6124
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step - accuracy: 0.2800 - loss: 1.5714
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step - accuracy: 0.3200 - loss: 1.5454
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step - accuracy: 0.3200 - loss: 1.5247
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step - accuracy: 0.3200 - loss: 1.5040
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step - accuracy: 0.2800 - loss: 1.5097
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.2800 - loss: 1.4875
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.3200 - loss: 1.4762
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 753ms/step - accuracy: 0.3200 - loss: 1.4679
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step - accuracy: 0.3200 - loss: 1.4576
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step - accuracy: 0.3200 - loss: 1.4499
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step - accuracy: 0.3200 - loss: 1.4444
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.3200 - loss: 1.4280
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.3200 - loss: 1.4323
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.3200 - loss: 1.4232
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.3200 - loss: 1.4024
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.3200 - loss: 1.4018
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.3200 - loss: 1.3926
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.3200 - loss: 1.3770
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.3200 - loss: 1.3587
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.4000 - loss: 1.3310
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.4000 - loss: 1.3077
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.4000 - loss: 1.2858
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.4000 - loss: 1.2570
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.4800 - loss: 1.2257
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.4800 - loss: 1.1959
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.4800 - loss: 1.1623
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.4800 - loss: 1.1319
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.5600 - loss: 1.1085
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5600 - loss: 1.0836
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.5200 - loss: 1.0649
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4800 - loss: 1.1004
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.6000 - loss: 1.0392
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.4800 - loss: 1.2117
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5600 - loss: 1.0596
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.5600 - loss: 1.0643
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.5600 - loss: 0.9822
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5200 - loss: 0.9706
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.5200 - loss: 1.0682
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.4800 - loss: 1.0572
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5200 - loss: 1.0333
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5600 - loss: 0.9814
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.6000 - loss: 0.9439
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.5600 - loss: 0.9442
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5600 - loss: 0.9416
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.6000 - loss: 0.9148
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6000 - loss: 0.8652
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.6400 - loss: 0.8289
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.6400 - loss: 0.8211
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6000 - loss: 0.8313
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.5600 - loss: 0.9647
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.7200 - loss: 0.8278
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6400 - loss: 0.8506
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.6800 - loss: 0.7476
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.6400 - loss: 0.7682
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.6400 - loss: 0.8102
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7600 - loss: 0.7143
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7600 - loss: 0.6758
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7200 - loss: 0.6626
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7600 - loss: 0.6484
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7600 - loss: 0.6090
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7200 - loss: 0.6099
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8800 - loss: 0.5697
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8000 - loss: 0.5469
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8000 - loss: 0.5310
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.7600 - loss: 0.5203
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7600 - loss: 0.4845
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8400 - loss: 0.4510
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8400 - loss: 0.4344
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.8800 - loss: 0.4346
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.8400 - loss: 0.4616
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.8000 - loss: 0.4682
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.8000 - loss: 0.4231
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9600 - loss: 0.4085
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.8400 - loss: 0.4128

# %% [markdown]
# # Step 5: Plotting the training loss

# %%
# Plotting training loss
import matplotlib.pyplot as plt
plt.plot(history_glorot_adam.history['loss'])
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# # Awesome, now you have succesfully trained a transformers model.
# ### Now let's try some practice excercises

# %% [markdown]
# ## Practice excercise 1

# %% [markdown]
# In this practice exercise, let's train the model using "he_uniform" initializer instead of "glorot_uniform". Then, compare the training loss between model using "glorot_uniform" vs "he_uniform" initializers by plotting them using matplotlib

# %%
## Write your answer here

#Define the Self-Attention Layer
class SelfAttention(Layer):
    def __init__(self, **kwargs):
        super(SelfAttention, self).__init__(**kwargs)

    def build(self, input_shape):
        feature_dim = input_shape[-1]
        # Weight matrices for Q, K, V
        self.Wq = self.add_weight(shape=(feature_dim, feature_dim), 
                                  initializer='he_uniform', 
                                  trainable=True, 
                                  name='Wq')
        self.Wk = self.add_weight(shape=(feature_dim, feature_dim), 
                                  initializer='he_uniform', 
                                  trainable=True, 
                                  name='Wk')
        self.Wv = self.add_weight(shape=(feature_dim, feature_dim), 
                                  initializer='he_uniform', 
                                  trainable=True, 
                                  name='Wv')
        super(SelfAttention, self).build(input_shape)

    def call(self, inputs):
        # Linear projections
        q = K.dot(inputs, self.Wq)  # Query
        k = K.dot(inputs, self.Wk)  # Key
        v = K.dot(inputs, self.Wv)  # Value

        # Scaled Dot-Product Attention
        scores = K.batch_dot(q, k, axes=[2, 2])  # (batch, seq_len, seq_len)
        scores = scores / K.sqrt(K.cast(K.shape(k)[-1], dtype=K.floatx()))  # Scale
        attention_weights = K.softmax(scores, axis=-1)  # Normalize

        # Weighted sum of values
        output = K.batch_dot(attention_weights, v)  # (batch, seq_len, feature_dim)
        return output

    def compute_output_shape(self, input_shape):
        return input_shape

    
#Encoder
encoder_inputs = Input(shape=(max_input_length,))
encoder_embedding = Embedding(input_vocab_size, 256)(encoder_inputs)
encoder_lstm = LSTM(256, return_sequences=True, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
encoder_states = [state_h, state_c]

#Attention Mechanism
attention_layer = SelfAttention()(encoder_outputs)

#Decoder
decoder_inputs = Input(shape=(max_output_length - 1,))
decoder_embedding = Embedding(output_vocab_size, 256)(decoder_inputs)
decoder_lstm = LSTM(256, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_attention = SelfAttention()(decoder_outputs)  # Apply attention
decoder_dense = Dense(output_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_attention)

#Full Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


#Step 6: Train the Model
history_he = model.fit([input_sequences, decoder_input_data], decoder_output_data, epochs=100, batch_size=16)

#Plotting training losses for glorot_uniform and he_uniform inititalizers
import matplotlib.pyplot as plt
plt.plot(history_glorot_adam.history['loss'], label="glorot_uniform", color='red')
plt.plot(history_he.history['loss'], label="he_uniform", color='blue')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 21s 21s/step - accuracy: 0.0800 - loss: 2.8326
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step - accuracy: 0.2800 - loss: 2.7841
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.2400 - loss: 2.7297
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 577ms/step - accuracy: 0.2400 - loss: 2.6592
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step - accuracy: 0.2400 - loss: 2.5640
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.2400 - loss: 2.4438
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.2400 - loss: 2.3376
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step - accuracy: 0.2400 - loss: 2.3523
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step - accuracy: 0.2400 - loss: 2.3192
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 679ms/step - accuracy: 0.2800 - loss: 2.2349
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step - accuracy: 0.3200 - loss: 2.1817
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step - accuracy: 0.2800 - loss: 2.1521
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step - accuracy: 0.2000 - loss: 2.1193
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step - accuracy: 0.2800 - loss: 2.0710
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.3200 - loss: 2.0050
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step - accuracy: 0.3200 - loss: 1.9268
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 836ms/step - accuracy: 0.3200 - loss: 1.8513
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step - accuracy: 0.3200 - loss: 1.7999
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step - accuracy: 0.3200 - loss: 1.7789
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 676ms/step - accuracy: 0.3200 - loss: 1.7597
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 824ms/step - accuracy: 0.3200 - loss: 1.7220
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step - accuracy: 0.3200 - loss: 1.6822
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step - accuracy: 0.3200 - loss: 1.6565
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 872ms/step - accuracy: 0.3200 - loss: 1.6319
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step - accuracy: 0.3200 - loss: 1.5876
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step - accuracy: 0.3200 - loss: 1.5364
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 656ms/step - accuracy: 0.3200 - loss: 1.5135
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step - accuracy: 0.3200 - loss: 1.4975
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step - accuracy: 0.3200 - loss: 1.5020
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step - accuracy: 0.3200 - loss: 1.4946
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step - accuracy: 0.3200 - loss: 1.4673
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step - accuracy: 0.3200 - loss: 1.4470
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.3200 - loss: 1.4107
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step - accuracy: 0.3200 - loss: 1.4124
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step - accuracy: 0.3600 - loss: 1.3987
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.3200 - loss: 1.3789
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 739ms/step - accuracy: 0.4000 - loss: 1.3552
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step - accuracy: 0.4400 - loss: 1.3292
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step - accuracy: 0.3600 - loss: 1.2860
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.4000 - loss: 1.2545
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step - accuracy: 0.4400 - loss: 1.2345
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.4400 - loss: 1.2013
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s
# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
#
#
# #Define the Self-Attention Layer
# class SelfAttention(Layer):
#     def __init__(self, **kwargs):
#         super(SelfAttention, self).__init__(**kwargs)
#
#     def build(self, input_shape):
#         feature_dim = input_shape[-1]
#         # Weight matrices for Q, K, V
#         self.Wq = self.add_weight(shape=(feature_dim, feature_dim),
#                                   initializer='he_uniform',
#                                   trainable=True,
#                                   name='Wq')
#         self.Wk = self.add_weight(shape=(feature_dim, feature_dim),
#                                   initializer='he_uniform',
#                                   trainable=True,
#                                   name='Wk')
#         self.Wv = self.add_weight(shape=(feature_dim, feature_dim),
#                                   initializer='he_uniform',
#                                   trainable=True,
#                                   name='Wv')
#         super(SelfAttention, self).build(input_shape)
#
#     def call(self, inputs):
#         # Linear projections
#         q = K.dot(inputs, self.Wq)  # Query
#         k = K.dot(inputs, self.Wk)  # Key
#         v = K.dot(inputs, self.Wv)  # Value
#
#         # Scaled Dot-Product Attention
#         scores = K.batch_dot(q, k, axes=[2, 2])  # (batch, seq_len, seq_len)
#         scores = scores / K.sqrt(K.cast(K.shape(k)[-1], dtype=K.floatx()))  # Scale
#         attention_weights = K.softmax(scores, axis=-1)  # Normalize
#
#         # Weighted sum of values
#         output = K.batch_dot(attention_weights, v)  # (batch, seq_len, feature_dim)
#         return output
#
#     def compute_output_shape(self, input_shape):
#         return input_shape
#
#
# #Encoder
# encoder_inputs = Input(shape=(max_input_length,))
# encoder_embedding = Embedding(input_vocab_size, 256)(encoder_inputs)
# encoder_lstm = LSTM(256, return_sequences=True, return_state=True)
# encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
# encoder_states = [state_h, state_c]
#
# #Attention Mechanism
# attention_layer = SelfAttention()(encoder_outputs)
#
# #Decoder
# decoder_inputs = Input(shape=(max_output_length - 1,))
# decoder_embedding = Embedding(output_vocab_size, 256)(decoder_inputs)
# decoder_lstm = LSTM(256, return_sequences=True, return_state=True)
# decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
# decoder_attention = SelfAttention()(decoder_outputs)  # Apply attention
# decoder_dense = Dense(output_vocab_size, activation='softmax')
# decoder_outputs = decoder_dense(decoder_attention)
#
# #Full Model
# model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#
#
# #Step 6: Train the Model
# history_he = model.fit([input_sequences, decoder_input_data], decoder_output_data, epochs=100, batch_size=16)
#
# #Plotting training losses for glorot_uniform and he_uniform inititalizers
# import matplotlib.pyplot as plt
# plt.plot(history_glorot_adam.history['loss'], label="glorot_uniform", color='red')
# plt.plot(history_he.history['loss'], label="he_uniform", color='blue')
# plt.title('Training Loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()
# -->

# %% [markdown]
# ## Practice excercise 2

# %% [markdown]
# In this practice exercise, try to use adaptive gradient optimizer instead of adam. Then, plot and compare the results between adam and adaptive gradient optimizers

# %%
### Write your answer here

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adagrad', loss='categorical_crossentropy', metrics=['accuracy'])

history_adagrad = model.fit([input_sequences, decoder_input_data], decoder_output_data, epochs=100, batch_size=16)

#Plotting training losses for glorot_uniform and he_uniform inititalizers
import matplotlib.pyplot as plt
plt.plot(history_glorot_adam.history['loss'], label="adam", color='red')
plt.plot(history_adagrad.history['loss'], label="adagrad", color='blue')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.0400 - loss: 2.8336
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.0400 - loss: 2.8333
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.1600 - loss: 2.8329
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.1600 - loss: 2.8326
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.2400 - loss: 2.8323
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.2400 - loss: 2.8321
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.2400 - loss: 2.8318
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.2400 - loss: 2.8315
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.2400 - loss: 2.8312
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.2400 - loss: 2.8310
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.2400 - loss: 2.8307
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.2400 - loss: 2.8304
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.2400 - loss: 2.8302
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.2400 - loss: 2.8299
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.2400 - loss: 2.8297
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.2400 - loss: 2.8294
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.2400 - loss: 2.8292
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0